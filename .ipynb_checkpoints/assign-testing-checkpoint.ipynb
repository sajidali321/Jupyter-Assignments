# %% [markdown]
# ## Assignment 1

# %%
# variable assign
a = 15
b = 4

# %%
# Add a and b
print (a + b )
# Out:
# 19

# %%
# Sub a and b
print ( a - b)
# Out:
# 11

# %%
# Product a and b
print (a * b)
# Out:
# 60

# %%
# Division a and b
print (a / b)
# Out:
# 3.75

# %%
# Floor Division a and b
print (a // b)
# Out:
# 3

# %%
# Modulus a and b
print (a % b)
# Out:
# 3

# %% [markdown]
# ## Solve Q2

# %%
fav_food1 = "Biryani"

# %%
print ("my fav food is :", fav_food1)
# Out:
# my fav food is : Biryani

# %%
fav_food2 = "Pizza"

# %%
print ("my fav food is :", fav_food2)
# Out:
# my fav food is : Pizza

# %% [markdown]
# ## Solve Q3

# %%
# Variable Assign
apple = '22'
mangoes = 33

# %%
total_fruits = int(apple) + mangoes

# %%
print ("Total Apple and Mangoes :", total_fruits)
# Out:
# Total Apple and Mangoes : 55

# %% [markdown]
# ## Solve Q4

# %%
# Variables Assign
num1 = 10
num2 = 5.6
num3 = 4.43
num4 = '23'

# %%
# Check types
print("Type of num1:", type(num1))
print("Type of num2:", type(num2))
print("Type of num3:", type(num3))
print("Type of num4:", type(num4))
# Out:
# Type of num1: <class 'int'>
# Type of num2: <class 'float'>
# Type of num3: <class 'float'>
# Type of num4: <class 'str'>

# %%
# Integer to Float
int_to_float = float(num1)

# %%
# print Integer to Float
print (int_to_float)
# Out:
# 10.0

# %%
# Float to Integer
float_to_integer = int(num2)

# %%
# print Float to Integer
print (float_to_integer)
# Out:
# 5

# %%
# Float to String
float_to_string = str(num3)

# %%
#print float to string
print (float_to_string)
# Out:
# 4.43

# %%
# String to Integer
string_to_integer = int(num4)

# %%
print (string_to_integer)
# Out:
# 23

# %% [markdown]
# ## Solve Q5

# %%
name = "Syed Sajid Ali"
age = 53

# %%
age = age + 1

# %%
print ("Syed Sajid Ali age is :", age)
# Out:
# Syed Sajid Ali age is : 54

# %% [markdown]
# ## Solve Q6

# %%
# 1. Variables ko assign kiya
a = 2
b = 1
c = 6
d = 3

# %%
print("Add a and b:", a + b)
# Out:
# Add a and b: 3

# %%
print("Subtract c and a:", c - a)
# Out:
# Subtract c and a: 4

# %%
print("Multiply d and b:", d * b)
# Out:
# Multiply d and b: 3

# %%
print("Divide c and d (float division):", c / d)
# Out:
# Divide c and d (float division): 2.0

# %%
print("Modulus of c divided by d:", c % d)
# Out:
# Modulus of c divided by d: 0

# %%
square_result = (d + a) ** 2

# %%
print("Square of (d+a):", square_result)
# Out:
# Square of (d+a): 25

# %% [markdown]
# ## Solve Q7

# %%
# variable age assign
age = 20

# %%
age = age + 5

# %%
print ("Age is :", age)
# Out:
# Age is : 25

# %% [markdown]
# ## Solve Q8

# %%
# Sab se pehle variables assign karein
a = '2'
b = '11'
c = 6.3

# %%
# 1. Convert a to integer then add to c
result1 = int(a) + c

# %%
print ("Convert a to integer then add to c :", result1)
# Out:
# Convert a to integer then add to c : 8.3

# %%
# 2. Convert b to float then multiply by c
result2 = float(b) * c

# %%
print ("Convert b to float then multiply by c :", result2)
# Out:
# Convert b to float then multiply by c : 69.3

# %%
# 3. Convert c to integer then add to c
result3 = int(c) + c

# %%
print("Convert c to integer then add to c :", result3)
# Out:
# Convert c to integer then add to c : 12.3

# %% [markdown]
# ## Solve Q9

# %%
# variable Assign
books = 12

# %%
# 4 books gave to friend
books = books - 4

# %%
print ("Remaining Books:", books)
# Out:
# Remaining Books: 8

# %% [markdown]
# ## Solve Q10

# %%
# cookies ko variable mein store kia
cookies = 5

# %%
# baked 3 times more today
cookies = cookies * 3

# %%
print ("cookies baked 3 times more :", cookies)
# Out:
# cookies baked 3 times more : 15

# %% [markdown]
# ## Solve Q11

# %%
# Original Expression: 20 - 4 * (3 + 2) + 18 / 3

# %%
Solve = 3+2

# %%
Solve
# Out:
# 5

# %%
Solve2 = 4 * 5

# %%
Solve2
# Out:
# 20

# %%
Solve3 = 18 / 3

# %%
Solve3
# Out:
# 6.0

# %%
Solve4 = 20-20

# %%
Solve4
# Out:
# 0

# %%
print("Result is :", Solve3)
# Out:
# Result is : 6.0
