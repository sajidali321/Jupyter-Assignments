# %% [markdown]
# # Practice

# %%
type y = 2+8

# %%
y = 2+8

# %%
y
# Out:
# 10

# %%
name = 15*2

# %%
name
# Out:
# 30

# %%
abc = 1600 * 2 / 100

# %%
abc
# Out:
# 32.0

# %%
3**5
# Out:
# 243

# %%
sa = 100/2

# %%
sa
# Out:
# 50

# %%
100/2
# Out:
# 50.0

# %%
200//3
# Out:
# 66

# %%
name = "Sajid"

# %%
name
# Out:
# 'Sajid'

# %%
vv = 15-10

# %%
vv
# Out:
# 5

# %%
15*4
# Out:
# 60

# %%
print (100+20)
# Out:
# 120

# %%
name = "Sajid"

# %%
print ("Sajid")
# Out:
# Sajid

# %%
print ("Hello World")
# Out:
# Hello World

# %%
print (1000*100)
# Out:
# 100000

# %%
number = 1972

# %%
number
# Out:
# 1972

# %%
y
# Out:
# 10

# %%
y + 25
# Out:
# 35

# %%
y = 35

# %%
y - 10
# Out:
# 25

# %%
print ("""We are learning Python""")
# Out:
# We are learning Python

# %%
print ("We are learning Python")
# Out:
# We are learning Python

# %%
print ('We are learning Python')
# Out:
# We are learning Python

# %%
print ('''we are learning Python''')
# Out:
# we are learning Python

# %%
x = 99.99

# %%
x
# Out:
# 99.99

# %%
x = "99.99"

# %%
x
# Out:
# '99.99'

# %%
x = 99.99
print(x + 1)
# Out:
# 100.99

# %%
x = "99.99"
print(x + "1")
# Out:
# 99.991

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
(type(x))
# Out:
# str

# %%
name = "Sajid"
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(x))
print(type(name))
# Out:
# <class 'str'>
# <class 'str'>

# %%
type (x)
# Out:
# str

# %%
nd = 120.50

# %%
type (nd)
# Out:
# float

# %%
nd
# Out:
# 120.5
