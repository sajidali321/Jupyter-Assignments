# %% [markdown]
# # Session 2

# %%
2+5
# Out:
# 7

# %%
print ("Hello World")
# Out:
# Hello World

# %%
3+3
# Out:
# 6

# %%
3**2
# Out:
# 9

# %%
10/2
# Out:
# 5.0

# %%
18//2 # floor div
# Out:
# 9

# %%
10%2 # modular
# Out:
# 0

# %%
print (10%2)
# Out:
# 0

# %% [markdown]
# # variable

# %%
x = "sara"
x
# Out:
# 'sara'

# %%
name = "Sajid"
name
# Out:
# 'Sajid'

# %%
name = "Sajid"
print (name)
# Out:
# Sajid

# %%
3-2 # sub
# Out:
# 1

# %%
3*2 # mul
# Out:
# 6

# %%
3**2
# Out:
# 9

# %%
3+6
# Out:
# 9

# %%
print (3+6)
# Out:
# 9

# %%
print (3*6)
# Out:
# 18

# %%
print ("Sajid")
# Out:
# Sajid

# %%
15%2
# Out:
# 1

# %%
type (name)
# Out:
# str

# %%
y = 10

# %%
y
# Out:
# 10

# %%
y+20
# Out:
# 30

# %%
y+50
# Out:
# 60

# %%
y = y+20+10

# %%
y
# Out:
# 40

# %%
z = 30

# %%
z
# Out:
# 30

# %%
y + z
# Out:
# 70

# %%
my name = "Sajid"
# Out:
#   Cell In[55], line 1
#     my name = "Sajid"
#        ^
# SyntaxError: invalid syntax

# %%
my_name "Sajid"
# Out:
#   Cell In[52], line 1
#     my_name "Sajid"
#             ^
# SyntaxError: invalid syntax

# %%
my_name = "Sajid"

# %%
my_name
# Out:
# 'Sajid'

# %%
number = 123

# %%
number
# Out:
# 123

# %%
y = 50

# %%
y
# Out:
# 50

# %%
y - 10
# Out:
# 40

# %%
y - 30
# Out:
# 20

# %%
z
# Out:
# 30

# %%
z - y
# Out:
# -20

# %%
y - z
# Out:
# 20

# %%
y = 10

# %%
y + 40
# Out:
# 50

# %%
y = y + 40

# %%
y
# Out:
# 50

# %%
abc = 100

# %%
abc = abc - 50

# %%
abc
# Out:
# 50

# %%
abc = 500

# %%
abc = abc - 300

# %%
abc
# Out:
# 200

# %%
print ("""We are Learning Python""")
# Out:
# We are Learning Python

# %%
print ('''I am Sajid''')
# Out:
# I am Sajid

# %%
xyz = 1000

# %%
xyz
# Out:
# 1000

# %%
xyz = xyz - 500

# %%
xyz
# Out:
# 500

# %%
2+3 # add
# Out:
# 5

# %%
3*2 # mul
# Out:
# 6

# %%
3**2 # Square
# Out:
# 9

# %%
10/2 # duv
# Out:
# 5.0

# %%
10//2 # Floor
# Out:
# 5

# %%
float (123)
# Out:
# 123.0

# %%
str (400)
# Out:
# '400'

# %%
int (123)
# Out:
# 123

# %%
float (123)
# Out:
# 123.0

# %%
float (456.29)
# Out:
# 456.29

# %%
str (333)
# Out:
# '333'

# %%
type(float (456.29))
# Out:
# float
