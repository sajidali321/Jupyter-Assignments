# %%
print ("Hello")
# Out:
# Hello

# %%
type ("Hello")
# Out:
# str

# %%
123
# Out:
# 123

# %%
type (123)
# Out:
# int

# %%
type (1345.89)
# Out:
# float

# %%
1345.89
# Out:
# 1345.89

# %%
print (500)
print (300)
print (200)
# Out:
# 500
# 300
# 200
