# %% [markdown]
# ## Solve Q1

# %%
a = 15

# %%
b = 4

# %%
print (a + b)
# Out:
# 19

# %%
print (a - b)
# Out:
# 11

# %%
print (a * b)
# Out:
# 60

# %%
print (a / b)
# Out:
# 3.75

# %%
print (a // b)
# Out:
# 3

# %%
print (a % b)
# Out:
# 3

# %% [markdown]
# ## Solve Q2

# %%
fav_food = "Biryani"

# %%
fav_food
# Out:
# 'Biryani'

# %%
favorite_food = "Pizza, Burger, Chicken Roll"

# %%
favorite_food
# Out:
# 'Pizza, Burger, Chicken Roll'

# %%
fav_food = "Pizza"

print("My favorite food is", fav_food)
# Out:
# My favorite food is Pizza

# %% [markdown]
# ## Solve Q3

# %%
apple = '22'
mangoes = 33

# %%
total_fruits = int(apple) + mangoes

# %%
print ("I have", total_fruits, "fruits in total.")
# Out:
# I have 55 fruits in total.

# %%
print("Total fruits =", total_fruits)
# Out:
# Total fruits = 55
