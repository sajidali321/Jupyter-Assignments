# %% [markdown]
# ## Solve Q6

# %%
# Variables
a = 2
b = 1
c = 6
d = 3

# %%
# 1. Add a and b
add = a + b

# %%
print("Addition of a and b:", addition)
# Out:
# Addition of a and b: 3

# %%
# 2. Subtract c and a
subtraction = c - a

# %%
print("Subtraction of c and a:", subtraction)
# Out:
# Subtraction of c and a: 4

# %%
# 3. Multiply d and b
multiplication = d * b

# %%
print("Multiplication of d and b:", multiplication)
# Out:
# Multiplication of d and b: 3

# %%
# 4. Divide c and d (float division)
division = c / d

# %%
print("Division of c and d (float):", division)
# Out:
# Division of c and d (float): 2.0

# %%
# 5. Find modulus of c divided by d
modulus = c % d

# %%
print("Modulus of c divided by d:", modulus)
# Out:
# Modulus of c divided by d: 0

# %%
# 6. Square of (d+a)
square_result = (d + a) ** 2

# %%
print("Square of (d+a):", square_result)
# Out:
# Square of (d+a): 25
