# %%
# Original Expression: 20 - 4 * (3 + 2) + 18 / 3

# %%
Solve = 3+2

# %%
Solve
# Out:
# 5

# %%
Solve2 = 4 * 5

# %%
Solve2
# Out:
# 20

# %%
Solve3 = 18 / 3

# %%
Solve3
# Out:
# 6.0

# %%
Solve4 = 20-20

# %%
Solve4
# Out:
# 0

# %%
print("Result is :", Solve3)
# Out:
# Result is : 6.0
