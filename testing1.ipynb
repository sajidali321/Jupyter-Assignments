# %%
print ("**Syed Sajid Ali**")
# Out:
# **Syed Sajid Ali**

# %% [markdown]
# ##### Syed Sajid Ali #####

# %% [markdown]
# '''We are learning Python'''

# %%
"""We are Learning Python"""
# Out:
# 'We are Learning Python'

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print ("We are learning Python")
# Out:
# We are learning Python

# %%
print ("""We are learning Python""")
# Out:
# We are learning Python

# %%
type (print)
# Out:
# builtin_function_or_method

# %%
type (234)
# Out:
# int

# %%
type ("123")
# Out:
# str

# %%
type (234.60)
# Out:
# float
