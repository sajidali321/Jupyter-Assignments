# %%
print("hello world")
# Out:
# hello world

# %%
type("hello world")
# Out:
# str

# %%
type(234)
# Out:
# int

# %%
type(23.45)
# Out:
# float

# %%
type("a")
# Out:
# str

# %%
type('a')
# Out:
# str
